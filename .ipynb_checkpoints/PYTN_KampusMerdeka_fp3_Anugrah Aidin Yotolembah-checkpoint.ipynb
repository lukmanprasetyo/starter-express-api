# %% [markdown]
# ![download.png](attachment:download.png)

# %% [markdown]
# # Final Project 3

# %% [markdown]
# Team :
# 1. Anugrah Aidin Yotolembah - PYTN-KS09-023
# 2.
# 3.
#
# Python for Data Science - Studi Independen - Kampus Merdeka

# %% [markdown]
# # A. Perkenalan

# %% [markdown]
# ## Latar Belakang
#
# Penyakit kardiovaskular (CVDs) adalah penyebab kematian nomor 1 secara global, mengambil sekitar 17,9 juta jiwa setiap tahun, yang menyumbang 31% dari semua kematian di seluruh dunia.
# Gagal jantung adalah kejadian umum yang disebabkan oleh CVD dan kumpulan data ini berisi 12 fitur yang dapat digunakan untuk memprediksi kematian akibat gagal jantung.
#
# Sebagian besar penyakit kardiovaskular dapat dicegah dengan mengatasi faktor risiko perilaku seperti penggunaan tembakau, diet tidak sehat dan obesitas, kurangnya aktivitas fisik, dan penggunaan alkohol yang berbahaya menggunakan strategi di seluruh populasi.
#
# Orang dengan penyakit kardiovaskular atau yang berada pada risiko kardiovaskular tinggi (karena adanya satu atau lebih faktor risiko seperti hipertensi, diabetes, hiperlipidemia atau penyakit yang sudah ada) memerlukan deteksi dan manajemen dini di mana model pembelajaran mesin dapat sangat membantu.
#
# dalam final project kali ini kami memakai dataset heart_failure_clinical_records_dataset.csv (Heart Failure Prediction), dataset ini berisi kumpulan banyak informasi dari penyebab penyakit kardiovaskular (CVDs). informasi di dalamnya juga bisa di olah datanya sebagai informasi data yang berguna

# %% [markdown]
# ## Objektif
# pada Final Project 2 ini yang harus di capai adalah :
#
# - Mampu memahami konsep Classification dengan Ensemble Model
# - Mampu mempersiapkan data untuk digunakan dalam Ensemble Model
# - Mampu mengimplementasikan Ensemble Model untuk membuat prediksi

# %% [markdown]
# # B. Import Pustaka
# Bagian dan Program kali ini berisi untuk menggunakan library untuk melakukan preprocesing, visualisasi dan library untuk modelling.

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
from sklearn import preprocessing
from sklearn.model_selection import train_test_split
import pickle

import warnings
warnings.filterwarnings("ignore")

print('library sudah siap !!')
# Out:
# library sudah siap !!

# %% [markdown]
# # C. Data Loading
# Bagian ini berisi proses data loading yang kemudian dilanjutkan dengan
# explorasi data secara sederhana.

# %% [markdown]
# 1. Memasukkan Dataset, dataset yang di pakai pada program ini ialah dataset Heart Failure Prediction, lalu menampilkan data teratas dan terbawah.

# %%
df = pd.read_csv('dataset/heart_failure_clinical_records_dataset.csv')
df

print("dataset sudah siap !!")
# Out:
# dataset sudah siap !!

# %%
df.head()
# Out:
#     age  anaemia  creatinine_phosphokinase  diabetes  ejection_fraction  \
# 0  75.0        0                       582         0                 20
# 1  55.0        0                      7861         0                 38
# 2  65.0        0                       146         0                 20
# 3  50.0        1                       111         0                 20
# 4  65.0        1                       160         1                 20
#
#    high_blood_pressure  platelets  serum_creatinine  serum_sodium  sex  \
# 0                    1  265000.00               1.9           130    1
# 1                    0  263358.03               1.1           136    1
# 2                    0  162000.00               1.3           129    1
# 3                    0  210000.00               1.9           137    1
# 4                    0  327000.00               2.7           116    0
#
#    smoking  time  DEATH_EVENT
# 0        0     4            1
# 1        0     6            1
# ...

# %%
df.tail()
# Out:
#       age  anaemia  creatinine_phosphokinase  diabetes  ejection_fraction  \
# 294  62.0        0                        61         1                 38
# 295  55.0        0                      1820         0                 38
# 296  45.0        0                      2060         1                 60
# 297  45.0        0                      2413         0                 38
# 298  50.0        0                       196         0                 45
#
#      high_blood_pressure  platelets  serum_creatinine  serum_sodium  sex  \
# 294                    1   155000.0               1.1           143    1
# 295                    0   270000.0               1.2           139    0
# 296                    0   742000.0               0.8           138    0
# 297                    0   140000.0               1.4           140    1
# 298                    0   395000.0               1.6           136    1
#
#      smoking  time  DEATH_EVENT
# 294        1   270            0
# ...

# %% [markdown]
# bisa di lihat terdapat informasi yang banyak ketika menampilkan 5 informasi teratas dan terbawah yang berada di dalam dataset

# %% [markdown]
# 2. Selanjutnya menampilkan informasi mengenai tipe data, range index, dan jumlah kolom yang berada dan terpakai di dalam dataset.

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 299 entries, 0 to 298
# Data columns (total 13 columns):
#  #   Column                    Non-Null Count  Dtype
# ---  ------                    --------------  -----
#  0   age                       299 non-null    float64
#  1   anaemia                   299 non-null    int64
#  2   creatinine_phosphokinase  299 non-null    int64
#  3   diabetes                  299 non-null    int64
#  4   ejection_fraction         299 non-null    int64
#  5   high_blood_pressure       299 non-null    int64
#  6   platelets                 299 non-null    float64
#  7   serum_creatinine          299 non-null    float64
#  8   serum_sodium              299 non-null    int64
#  9   sex                       299 non-null    int64
#  10  smoking                   299 non-null    int64
#  11  time                      299 non-null    int64
#  12  DEATH_EVENT               299 non-null    int64
# dtypes: float64(3), int64(10)
# memory usage: 30.5 KB

# %% [markdown]
# setelah mencari informasi yang berada di dalam dataset, terdapat 13 columns pada dataset, terdapat 2 jenis tipe data yatu tipe data float64 dan int64. dan terdapat rangeindex sebanyak 299 entries.

# %% [markdown]
# 3. Selanjutnya menampilkan informasi data statistik deskriptif pada masing masing atribut yang bertipe numerik

# %%
df.describe()
# Out:
#               age     anaemia  creatinine_phosphokinase    diabetes  \
# count  299.000000  299.000000                299.000000  299.000000
# mean    60.833893    0.431438                581.839465    0.418060
# std     11.894809    0.496107                970.287881    0.494067
# min     40.000000    0.000000                 23.000000    0.000000
# 25%     51.000000    0.000000                116.500000    0.000000
# 50%     60.000000    0.000000                250.000000    0.000000
# 75%     70.000000    1.000000                582.000000    1.000000
# max     95.000000    1.000000               7861.000000    1.000000
#
#        ejection_fraction  high_blood_pressure      platelets  \
# count         299.000000           299.000000     299.000000
# mean           38.083612             0.351171  263358.029264
# std            11.834841             0.478136   97804.236869
# min            14.000000             0.000000   25100.000000
# ...

# %% [markdown]
# setelah mencari informasi data statistik deskriptif pada dataset, terdapa informasi yang sangat banyak seperti informasi nilai rata rata pada dataset, nilai maximum dan minimum pada dataset, dan informasi penting lainnya.

# %% [markdown]
# 4. Selanjutnya menampilkan nama pada columns yang berada di dalam dataset

# %%
df.columns
# Out:
# Index(['age', 'anaemia', 'creatinine_phosphokinase', 'diabetes',
#        'ejection_fraction', 'high_blood_pressure', 'platelets',
#        'serum_creatinine', 'serum_sodium', 'sex', 'smoking', 'time',
#        'DEATH_EVENT'],
#       dtype='object')

# %% [markdown]
# bisa di lihat terdapat 13 columns dengan nama nama berbeda

# %% [markdown]
# 5. Selanjutnya Menampilkan informasi tentang jumlah baris dan kolom yang berada di dalam dataset ini

# %%
df.shape
# Out:
# (299, 13)

# %% [markdown]
# bisa di lihat bahwa pada dataset ini terdapat 13 columns dan 299 baris

# %% [markdown]
# # D. Data Cleaning
#
# Bagian ini berisi proses penyiapan data berupa data cleaning sebelum
# dilakukan explorasi data lebih lanjut. Proses cleaning dapat berupa
# memberi nama baru untuk setiap kolom, mengisi missing values,
# menghapus kolom yang tidak dipakai, dan lain sebagainya.

# %% [markdown]
# ## Mengecek Missing Value pada dataset

# %% [markdown]
# 1. Sebelum mengecek Missing Value pada dataset, terlebih dahulu mengecek kembali informasi pada dataset agar semua informasi pada dataset bisa tertampil semua

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 299 entries, 0 to 298
# Data columns (total 13 columns):
#  #   Column                    Non-Null Count  Dtype
# ---  ------                    --------------  -----
#  0   age                       299 non-null    float64
#  1   anaemia                   299 non-null    int64
#  2   creatinine_phosphokinase  299 non-null    int64
#  3   diabetes                  299 non-null    int64
#  4   ejection_fraction         299 non-null    int64
#  5   high_blood_pressure       299 non-null    int64
#  6   platelets                 299 non-null    float64
#  7   serum_creatinine          299 non-null    float64
#  8   serum_sodium              299 non-null    int64
#  9   sex                       299 non-null    int64
#  10  smoking                   299 non-null    int64
#  11  time                      299 non-null    int64
#  12  DEATH_EVENT               299 non-null    int64
# dtypes: float64(3), int64(10)
# memory usage: 30.5 KB

# %% [markdown]
# 2. Selanjutya Mengecek data yang terduplikat pada dataset

# %%
df.duplicated().sum()
# Out:
# 0

# %% [markdown]
# bisa di lihat bahwa informasi di atas menampilkan nilai 0 yang artinya tidak ada data yang terduplikat pada dataset

# %% [markdown]
# 3. Selanjutnya mengecek Missing Value pada dataset

# %%
df.isnull().sum()
# Out:
# age                         0
# anaemia                     0
# creatinine_phosphokinase    0
# diabetes                    0
# ejection_fraction           0
# high_blood_pressure         0
# platelets                   0
# serum_creatinine            0
# serum_sodium                0
# sex                         0
# smoking                     0
# time                        0
# DEATH_EVENT                 0
# dtype: int64

# %% [markdown]
# bisa di lihat bahwa informasi di atas menampilkan nilai 0 yang artinya tidak ada missing value  pada dataset

# %%
for col in df.columns:
    print(col, ':')
    print(df[col].value_counts())
    print(" ")
    print(" ")
# Out:
# age :
# 60.000    33
# 50.000    27
# 65.000    26
# 70.000    25
# 45.000    19
# 55.000    17
# 75.000    11
# 53.000    10
# 58.000    10
# 63.000     8
# 80.000     7
# 72.000     7
# 40.000     7
# 42.000     7
# 85.000     6
# 68.000     5
# 52.000     5
# 62.000     5
# 51.000     4
# 59.000     4
# 61.000     4
# 73.000     4
# 49.000     4
# 69.000     3
# 46.000     3
# 64.000     3
# 82.000     3
# 90.000     3
# 78.000     2
# 60.667     2
# 54.000     2
# 77.000     2
# 57.000     2
# 66.000     2
# 44.000     2
# 67.000     2
# 95.000     2
# 48.000     2
# 43.000     1
# 86.000     1
# 81.000     1
# 79.000     1
# 41.000     1
# 94.000     1
# 87.000     1
# 47.000     1
# 56.000     1
# Name: age, dtype: int64
#
#
# anaemia :
# 0    170
# 1    129
# Name: anaemia, dtype: int64
#
#
# creatinine_phosphokinase :
# 582     47
# 66       4
# 129      4
# 231      3
# 69       3
#         ..
# 748      1
# 1876     1
# 936      1
# 292      1
# 2413     1
# ...

# %% [markdown]
# bisa di lihat, terdapat nilai unik di setiap columns pada dataset ini

# %% [markdown]
# ## E. EDA : Explorasi Data Analysis
# Bagian ini berisi explorasi data pada dataset diatas dengan menggunakan
# query, grouping, visualisasi sederhana, dan lain sebagainya.

# %% [markdown]
# ### Explorasi Data
# setelah Melihat informasi data pada dataset mulai dari informasi 5 data teratas, 5 data terbawah di atas selanjutnya melihat informasi mengenai index range dan tipe data pada dataset, dan juga melihat informasi statistik value. berguna untuk saat melakukan visualisasi

# %%
df.head()
# Out:
#     age  anaemia  creatinine_phosphokinase  diabetes  ejection_fraction  \
# 0  75.0        0                       582         0                 20
# 1  55.0        0                      7861         0                 38
# 2  65.0        0                       146         0                 20
# 3  50.0        1                       111         0                 20
# 4  65.0        1                       160         1                 20
#
#    high_blood_pressure  platelets  serum_creatinine  serum_sodium  sex  \
# 0                    1  265000.00               1.9           130    1
# 1                    0  263358.03               1.1           136    1
# 2                    0  162000.00               1.3           129    1
# 3                    0  210000.00               1.9           137    1
# 4                    0  327000.00               2.7           116    0
#
#    smoking  time  DEATH_EVENT
# 0        0     4            1
# 1        0     6            1
# ...

# %%
df.tail()
# Out:
#       age  anaemia  creatinine_phosphokinase  diabetes  ejection_fraction  \
# 294  62.0        0                        61         1                 38
# 295  55.0        0                      1820         0                 38
# 296  45.0        0                      2060         1                 60
# 297  45.0        0                      2413         0                 38
# 298  50.0        0                       196         0                 45
#
#      high_blood_pressure  platelets  serum_creatinine  serum_sodium  sex  \
# 294                    1   155000.0               1.1           143    1
# 295                    0   270000.0               1.2           139    0
# 296                    0   742000.0               0.8           138    0
# 297                    0   140000.0               1.4           140    1
# 298                    0   395000.0               1.6           136    1
#
#      smoking  time  DEATH_EVENT
# 294        1   270            0
# ...

# %%
df.describe()
# Out:
#               age     anaemia  creatinine_phosphokinase    diabetes  \
# count  299.000000  299.000000                299.000000  299.000000
# mean    60.833893    0.431438                581.839465    0.418060
# std     11.894809    0.496107                970.287881    0.494067
# min     40.000000    0.000000                 23.000000    0.000000
# 25%     51.000000    0.000000                116.500000    0.000000
# 50%     60.000000    0.000000                250.000000    0.000000
# 75%     70.000000    1.000000                582.000000    1.000000
# max     95.000000    1.000000               7861.000000    1.000000
#
#        ejection_fraction  high_blood_pressure      platelets  \
# count         299.000000           299.000000     299.000000
# mean           38.083612             0.351171  263358.029264
# std            11.834841             0.478136   97804.236869
# min            14.000000             0.000000   25100.000000
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 299 entries, 0 to 298
# Data columns (total 13 columns):
#  #   Column                    Non-Null Count  Dtype
# ---  ------                    --------------  -----
#  0   age                       299 non-null    float64
#  1   anaemia                   299 non-null    int64
#  2   creatinine_phosphokinase  299 non-null    int64
#  3   diabetes                  299 non-null    int64
#  4   ejection_fraction         299 non-null    int64
#  5   high_blood_pressure       299 non-null    int64
#  6   platelets                 299 non-null    float64
#  7   serum_creatinine          299 non-null    float64
#  8   serum_sodium              299 non-null    int64
#  9   sex                       299 non-null    int64
#  10  smoking                   299 non-null    int64
#  11  time                      299 non-null    int64
#  12  DEATH_EVENT               299 non-null    int64
# dtypes: float64(3), int64(10)
# memory usage: 30.5 KB

# %%
df_1 =df[['age', 'diabetes']]
df_1
# Out:
#       age  diabetes
# 0    75.0         0
# 1    55.0         0
# 2    65.0         0
# 3    50.0         0
# 4    65.0         1
# ..    ...       ...
# 294  62.0         1
# 295  55.0         0
# 296  45.0         1
# 297  45.0         0
# 298  50.0         0
#
# [299 rows x 2 columns]

# %%
sp = df[['age', 'diabetes', 'sex']]
sns.catplot(data = sp, x = 'age', y = 'diabetes', hue= 'sex')
